# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(1, '../src')
import constants as const

# %%
df = pd.read_csv(const.DATA_CSV, delimiter=",", index_col=0)
df.head()
# Out:
#                                                     title  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...
# 2       Harry Potter and the Order of the Phoenix (Har...
# 4       Harry Potter and the Chamber of Secrets (Harry...
# 5       Harry Potter and the Prisoner of Azkaban (Harr...
# 8       Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                            authors average_rating        isbn         isbn13  \
# bookID
# 1       J.K. Rowling/Mary GrandPré           4.57   439785960  9780439785969
# 2       J.K. Rowling/Mary GrandPré           4.49   439358078  9780439358071
# 4                     J.K. Rowling           4.42   439554896  9780439554893
# 5       J.K. Rowling/Mary GrandPré           4.56  043965548X  9780439655484
# 8       J.K. Rowling/Mary GrandPré           4.78   439682584  9780439682589
#
#        language_code   num_pages  ratings_count  text_reviews_count  \
# bookID
# ...
